# %% [markdown]
# # Описание датасета на примере dummy набора

# %%
import pandas as pd

# %%
path = "parsed_data/mock_tweets.csv"

# %%
df = pd.read_csv(path, index_col=0)

# %%
df.head()
# Out:
#           id                                               text  \
# 0  623495513  #AAPL:The 10 best Steve Jobs emails ever...htt...
# 1  623495514  RT @JPDesloges: Why AAPL Stock Had a Mini-Flas...
# 2  623495515  My cat only chews @apple cords. Such an #Apple...
# 3  623495516  I agree with @jimcramer that the #IndividualIn...
# 4  623495517       Nobody expects the Spanish Inquisition #AAPL
#
#                         date     user  likes  retweets
# 0  2014-12-01 19:30:03+00:00  unknown    925        92
# 1  2014-12-01 19:43:51+00:00  unknown    531        16
# 2  2014-12-01 19:50:28+00:00  unknown    161        66
# 3  2014-12-01 20:26:34+00:00  unknown    719        42
# 4  2014-12-01 20:29:33+00:00  unknown     33        63

# %% [markdown]
# ## Самые лайкаемые твиты

# %%
df.sort_values("likes", ascending=False).head(20)
# Out:
#              id                                               text  \
# 565   623496078  @Shampeau @TheWeldingRoom @Apple @Monster @red...
# 2859  623498389  @apple your freaking computer went psycho and ...
# 2813  623498343            I just had 40% now I have 8% wtf @apple
# 805   623496318  @_LanaCarine_ @Apple doesn't have a twitter @A...
# 1070  623496589  How Competition Between Wireless Carriers Bene...
# 2191  623497721  #WearableDevices To #Consumers : You're Puttin...
# 3749  623499279  #Apple wins patent for #3D iPhone UI w/ motion...
# 618   623496131  You need to send me my IPhone before I cancel ...
# 2057  623497587  @THE_HIIT_COACH @weightsmate @Apple it's simil...
# 255   623495768  RT @laurrynk: Dear @apple replace my phone my ...
# 3070  623498600  @apple make a fucking phone so the screen does...
# 1197  623496716  @stevewoz @harveystahoe @apple Patent Number p...
# 228   623495741  @NeimanMarcus utilizing iBeacons for #engageme...
# ...

# %% [markdown]
# ## По количеству ретвитов

# %%
df.sort_values("retweets", ascending=False).head(20)
# Out:
#              id                                               text  \
# 3034  623498564  Steve Jobs Predicted Future Of E-Commerce Back...
# 1041  623496560  #AAPL:DexCom CEO Terry Gregg Explains 50% YTD ...
# 125   623495638  How long does it really take for a phone to sh...
# 1921  623497446  Apple: quarter 2014Q3 EPS is $1.42. Use it at ...
# 2608  623498138  GREAT READ: Why @Apple @Facebook and @Google c...
# 114   623495627  RT @elnuevoherald: Steve Jobs, clave en juicio...
# 2580  623498110  RT @Hi_IamAaron: Dear @Apple can u please stop...
# 2078  623497608  . @stevewoz: passion for engineering/design at...
# 3334  623498864  RT @TeamCavuto: Protesters stage #DieIn protes...
# 1087  623496606  @zoebread dps developments; welove #AAPL-E and...
# 3646  623499176  Why @Apple Won't Be A Trillion Dollar Company ...
# 1088  623496607  @APPLE IF YOU DIDNT MAKE SUCH GOOD PRODUCTS I ...
# 2172  623497702  why don't we have harry potter emojis please w...
# ...
